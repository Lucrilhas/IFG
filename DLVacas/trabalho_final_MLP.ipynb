# %% [markdown]
# **Deep Learning - Trabalho Conclusão de Módulo**
#
# > 27/04/2024

# %% [markdown]
# **Integrantes**
#
# - André Luiz Pires Guimarães
# - Daniel de Souza Miranda
# - Iago Nery Mendes
# - Lucas Elias de Andrade Cruvinel
# - Victor Hugo Brito da Silva Miranda

# %%
# !for a in /sys/bus/pci/devices/*; do echo 0 | sudo tee -a $a/numa_node; done
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %%
# !pip install --upgrade scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (3.4.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import tensorflow as tf
from keras import Sequential, Model, layers, callbacks, optimizers
#from keras.models import Sequential, Model
#from keras.layers import Dense, Flatten, Dropout, BatchNormalization
#from keras.callbacks import ModelCheckpoint
#from keras.optimizers import Adam
from sklearn.model_selection import GridSearchCV
#from keras.wrappers.scikit_learn import KerasClassifier
from scikeras.wrappers import KerasRegressor, KerasClassifier
import keras
# Out:
# 2024-05-04 02:49:58.932680: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-04 02:49:58.932730: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-04 02:49:58.934321: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-04 02:49:58.944546: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
keras.__version__
# Out:
# '3.3.3'

# %%
sklearn.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 sklearn.__version__
#
# NameError: name 'sklearn' is not defined

# %%
# physical_devices = tf.config.experimental.list_physical_devices('GPU')
# if len(physical_devices) > 0:
#     print(physical_devices)
#     tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
df_milk = pd.read_csv("milk.csv", parse_dates=["Date"])
df_milk.dropna(how='any', axis=0, inplace=True, ignore_index=True)
df_milk.shape
# Out:
# (25846, 10)

# %%
# Nome da coluna que deseja mover para a última posição
coluna = 'milk_production'

# Remover a coluna do DataFrame
coluna_removida = df_milk.pop(coluna)

# Inserir a coluna removida na última posição
df_milk.insert(len(df_milk.columns), coluna, coluna_removida)

# %%
df_milk.head()
# Out:
#    AnEar       Date  lactation  dim  MilkShif   Cond    Dur  Peak  dim2  \
# 0    123 2023-01-09          4    1     11.50  5.420  276.0   6.7     1
# 1    123 2023-01-10          4    2     24.20  4.945  384.0  15.0     2
# 2    123 2023-01-11          4    3     33.20  5.060  672.0  15.5     3
# 3    123 2023-01-12          4    4     28.55  4.940  354.0  16.4     4
# 4    123 2023-01-13          4    5     39.25  5.055  396.0  17.0     5
#
#    milk_production
# 0             11.5
# 1             48.4
# 2             66.4
# 3             57.1
# 4             78.5

# %%
df_milk.tail()
# Out:
#        AnEar       Date  lactation  dim  MilkShif   Cond    Dur  Peak  dim2  \
# 25841   9977 2023-12-13          2  301     36.40  4.980  540.0  13.8   301
# 25842   9977 2023-12-14          2  302     36.50  4.700  600.0  12.9   302
# 25843   9977 2023-12-15          2  303     35.45  5.075  540.0  13.3   303
# 25844   9977 2023-12-16          2  304     35.30  4.955  516.0  12.0   304
# 25845   9977 2023-12-17          2  305     33.85  4.960  522.0  12.3   305
#
#        milk_production
# 25841             72.8
# 25842             73.0
# 25843             70.9
# 25844             70.6
# 25845             67.7

# %%
df_milk['AnEar'].value_counts()
# Out:
# AnEar
# 123     305
# 8947    305
# 9066    305
# 9078    305
# 9081    305
#        ...
# 9525    304
# 9549    304
# 8064    304
# 7761    301
# 8732    259
# Name: count, Length: 85, dtype: int64

# %%
#Definindo as variáveis para o heatmap
variaveis = ['AnEar', 'lactation', 'dim', 'MilkShif', 'Cond', 'Dur', 'Peak', 'dim2', 'milk_production']

#Criando o heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df_milk[variaveis].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Heatmap das Variáveis')
plt.show()

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(12,6))
sns.lineplot(x=df_milk["Date"], y="milk_production", data=df_milk).set_title("Produção de Leite")
# Out:
# Text(0.5, 1.0, 'Produção de Leite')

# %% [markdown]
# Armotizando a visualização:

# %%
df_milk_am = pd.read_csv("milk.csv", parse_dates=["Date"])[["milk_production", "Date"]]
df_milk_am.set_index("Date", inplace=True)
df_milk_am.resample('10D').mean().plot(figsize=(12,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_milk_copy = df_milk.copy()

# %%
#df_milk.drop('AnEar', axis=1, inplace=True)
df_milk.drop('Date', axis=1, inplace=True)
df_milk.drop('Cond', axis=1, inplace=True)
df_milk.drop('Dur', axis=1, inplace=True)
df_milk.drop('Peak', axis=1, inplace=True)
df_milk.drop('dim2', axis=1, inplace=True)

# %%
df_milk.head()
# Out:
#    AnEar  lactation  dim  MilkShif  milk_production
# 0    123          4    1     11.50             11.5
# 1    123          4    2     24.20             48.4
# 2    123          4    3     33.20             66.4
# 3    123          4    4     28.55             57.1
# 4    123          4    5     39.25             78.5

# %% [markdown]
# Verificando a frequência da lactação

# %%
# Agrupar os dados pela combinação única de valores nas colunas 'AnEar' e 'lactation'
agrupado = df_milk_copy.groupby(['AnEar', 'lactation']).size().reset_index(name='count')
print(agrupado)

# Contar o número de vacas únicas para cada valor de lactation
frequencia = agrupado.groupby('lactation')['AnEar'].count()

# Exibir a frequência de vacas únicas com base no número de lactation
print("Frequência de vacas únicas com base no número de lactation:")
print((frequencia))
# Out:
#     AnEar  lactation  count
# 0     123          4    305
# 1    1009          2    305
# 2    1017          2    305
# 3    1209          1    305
# 4    1218          1    305
# ..    ...        ...    ...
# 80   9951          2    305
# 81   9961          2    305
# 82   9967          2    305
# 83   9968          2    304
# 84   9977          2    305
#
# [85 rows x 3 columns]
# Frequência de vacas únicas com base no número de lactation:
# lactation
# 1    14
# 2    26
# 3    16
# 4    15
# 5     5
# 6     7
# 7     1
# 8     1
# Name: AnEar, dtype: int64

# %%
codigos_vacas = np.array(df_milk_copy["AnEar"].unique())
print(codigos_vacas)
# Out:
# [ 123 1009 1017 1209 1218 1242 1243 1275 1280 1305 1327 1329 1341 1362
#  1368 1387 1393 7761 8064 8334 8385 8393 8434 8435 8438 8509 8581 8667
#  8723 8732 8741 8932 8947 8996 9005 9066 9069 9078 9081 9090 9101 9149
#  9188 9207 9284 9346 9363 9388 9389 9431 9463 9464 9478 9487 9488 9525
#  9529 9549 9558 9562 9583 9885 9891 9892 9894 9908 9909 9910 9917 9918
#  9920 9922 9926 9928 9929 9933 9939 9943 9944 9946 9951 9961 9967 9968
#  9977]

# %%
train = []
validation = []
test = []

# %%
df_milk[(df_milk['lactation'] == 4) & (df_milk['AnEar'] == 123)]
# Out:
#      AnEar  lactation  dim  MilkShif  milk_production
# 0      123          4    1     11.50             11.5
# 1      123          4    2     24.20             48.4
# 2      123          4    3     33.20             66.4
# 3      123          4    4     28.55             57.1
# 4      123          4    5     39.25             78.5
# ..     ...        ...  ...       ...              ...
# 300    123          4  301     24.65             49.3
# 301    123          4  302     23.00             46.0
# 302    123          4  303     24.80             49.6
# 303    123          4  304     23.30             46.6
# 304    123          4  305     23.90             47.8
#
# [305 rows x 5 columns]

# %%
teste_anear = df_milk[(df_milk['lactation'] == 4) & (df_milk['AnEar'] == 123)]
teste_anear
# Out:
#      AnEar  lactation  dim  MilkShif  milk_production
# 0      123          4    1     11.50             11.5
# 1      123          4    2     24.20             48.4
# 2      123          4    3     33.20             66.4
# 3      123          4    4     28.55             57.1
# 4      123          4    5     39.25             78.5
# ..     ...        ...  ...       ...              ...
# 300    123          4  301     24.65             49.3
# 301    123          4  302     23.00             46.0
# 302    123          4  303     24.80             49.6
# 303    123          4  304     23.30             46.6
# 304    123          4  305     23.90             47.8
#
# [305 rows x 5 columns]

# %% [markdown]
# # Separação de vacas
#
# Lógica utilizada atualmente

# %%
def janelas_da_vaca_2(df, nome_vaca, tam):
    tam_train = int(tam * 0.7)
    janelas_train = []
    janelas_val = []
    janelas_test = []
    input_vaca = df[df["AnEar"]==nome_vaca].to_numpy()
    target_vaca = df[df["AnEar"]==nome_vaca]["milk_production"].to_numpy()
    #print("Input vaca:", input_vaca[1][1:4])
    #print("Target vaca:", target_vaca[1])
    for i in range(tam_train):
        #print("i:", i)
        janelas_train.append([input_vaca[i][1:4], [target_vaca[i]]])
        #print("VACA", input[1:4])
    for j in range(tam_train, tam+1, 1):
        #print("j:", j, "tamanho:", range(tam_train+1, tam_train+1, 1))
        janelas_val.append([input_vaca[j-1][1:4], [target_vaca[j-1]]])
    for k in range(tam+1, len(input_vaca)+1, 1):
        #print("k:", k, "tamanho:", range(tam, len(input_vaca), 1))
        janelas_test.append([input_vaca[k-1][1:4], [target_vaca[k-1]]])

    return janelas_train, janelas_val, janelas_test

tam_janela = 50
janelas_2 = {'xtrain':[], 'xval':[], 'xtest':[], 'ytrain':[], 'yval':[], 'ytest':[]}
janelas_data = [janelas_da_vaca_2(df_milk, vaca, tam_janela) for vaca in codigos_vacas]
for janelas_treino, janelas_validacao, janelas_teste in janelas_data:
    for janela in janelas_treino:
        janelas_2["xtrain"].append(janela[0])
        janelas_2["ytrain"].append(janela[1])
    for janela in janelas_validacao:
        janelas_2["xval"].append(janela[0])
        janelas_2["yval"].append(janela[1])
    for janela in janelas_teste:
        janelas_2["xtest"].append(janela[0])
        janelas_2["ytest"].append(janela[1])

X_train, y_train = np.array(janelas_2["xtrain"]), np.array(janelas_2["ytrain"])
X_val, y_val = np.array(janelas_2["xval"]), np.array(janelas_2["yval"])
X_test, y_test = np.array(janelas_2["xtest"]), np.array(janelas_2["ytest"])

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (2975, 3) (2975, 1)
# (1360, 3) (1360, 1)
# (21596, 3) (21596, 1)

# %%
print("Input Treino:", X_train[1], "Target Treino:", y_train[1])
print("Input Validação:", X_train[0], "Target Validação:", y_train[0])
print("Input Teste:", X_train[0], "Target Teste:", y_train[0])
# Out:
# Input Treino: [ 4.   2.  24.2] Target Treino: [48.4]
# Input Validação: [ 4.   1.  11.5] Target Validação: [11.5]
# Input Teste: [ 4.   1.  11.5] Target Teste: [11.5]

# %%
xsc = MinMaxScaler().fit(X_train)
X_train = xsc.transform(X_train)
X_val = xsc.transform(X_val)
X_test = xsc.transform(X_test)

#X_train = X_train.reshape((len(X_train), tam_janela, 1))
#X_val = X_val.reshape((len(X_val), tam_janela, 1))
#X_test = X_test.reshape((len(X_test), tam_janela, 1))

ysc = MinMaxScaler().fit(y_train)
y_train = ysc.transform(y_train)
y_val = ysc.transform(y_val)
y_test = ysc.transform(y_test)

# %% [markdown]
# ## Construção da Rede Neural

# %%
def get_model(hidden_layer_sizes, dropout, learning_rate):
  model=Sequential()
  model.add(layers.InputLayer((3,)))
  model.add(layers.Flatten())
  model.add(layers.Dense(hidden_layer_sizes, activation="relu", kernel_initializer="he_uniform"))
  model.add(layers.Dropout(dropout))
  model.add(layers.BatchNormalization())
  model.add(layers.Dense(hidden_layer_sizes, activation="relu", kernel_initializer="he_uniform"))
  model.add(layers.Dropout(dropout))
  model.add(layers.BatchNormalization())
  model.add(layers.Dense(hidden_layer_sizes, activation="relu", kernel_initializer="he_uniform"))
  model.add(layers.Dropout(dropout))
  model.add(layers.BatchNormalization())
  model.add(layers.Dense(hidden_layer_sizes, activation="relu", kernel_initializer="he_uniform"))
  model.add(layers.Dropout(dropout))
  model.add(layers.Dense(1,activation="linear"))

  #final_model = Model([model.input], out)
  model.compile(loss='mean_absolute_error', optimizer=optimizers.Adam(learning_rate=learning_rate), metrics=['mae'])

  return model

# %%
model = get_model(dropout=0.3, hidden_layer_sizes=256, learning_rate=0.01)
model.fit(X_train, y_train, epochs=50, validation_data=(X_val,y_val))
# Out:
# Epoch 1/50
# 2024-05-04 02:57:55.222225: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13775 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2024-05-04 02:57:57.846913: I external/local_xla/xla/service/service.cc:168] XLA service 0x55e285e6d190 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-05-04 02:57:57.846950: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2024-05-04 02:57:57.966289: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-05-04 02:57:58.683805: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 57/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3365 - mae: 1.3365
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714791485.003875   21572 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 16s 75ms/step - loss: 1.0860 - mae: 1.0860 - val_loss: 0.1763 - val_mae: 0.1763
# Epoch 2/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1339 - mae: 0.1339 - val_loss: 0.0493 - val_mae: 0.0493
# Epoch 3/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0791 - mae: 0.0791 - val_loss: 0.1074 - val_mae: 0.1074
# Epoch 4/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0569 - mae: 0.0569 - val_loss: 0.0899 - val_mae: 0.0899
# Epoch 5/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0527 - mae: 0.0527 - val_loss: 0.0605 - val_mae: 0.0605
# Epoch 6/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0531 - mae: 0.0531 - val_loss: 0.0558 - val_mae: 0.0558
# Epoch 7/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0525 - mae: 0.0525 - val_loss: 0.0584 - val_mae: 0.0584
# Epoch 8/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0567 - mae: 0.0567 - val_loss: 0.0525 - val_mae: 0.0525
# Epoch 9/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0505 - mae: 0.0505 - val_loss: 0.0517 - val_mae: 0.0517
# Epoch 10/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0539 - mae: 0.0539 - val_loss: 0.0704 - val_mae: 0.0704
# Epoch 11/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0499 - mae: 0.0499 - val_loss: 0.0585 - val_mae: 0.0585
# Epoch 12/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0517 - mae: 0.0517 - val_loss: 0.0366 - val_mae: 0.0366
# Epoch 13/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0541 - mae: 0.0541 - val_loss: 0.0335 - val_mae: 0.0335
# Epoch 14/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0539 - mae: 0.0539 - val_loss: 0.0391 - val_mae: 0.0391
# Epoch 15/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0496 - mae: 0.0496 - val_loss: 0.0151 - val_mae: 0.0151
# Epoch 16/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0465 - mae: 0.0465 - val_loss: 0.0375 - val_mae: 0.0375
# Epoch 17/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0460 - mae: 0.0460 - val_loss: 0.0335 - val_mae: 0.0335
# Epoch 18/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0476 - mae: 0.0476 - val_loss: 0.0299 - val_mae: 0.0299
# Epoch 19/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0470 - mae: 0.0470 - val_loss: 0.0244 - val_mae: 0.0244
# Epoch 20/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0458 - mae: 0.0458 - val_loss: 0.0167 - val_mae: 0.0167
# Epoch 21/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0451 - mae: 0.0451 - val_loss: 0.0234 - val_mae: 0.0234
# Epoch 22/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0421 - mae: 0.0421 - val_loss: 0.0474 - val_mae: 0.0474
# Epoch 23/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0445 - mae: 0.0445 - val_loss: 0.0472 - val_mae: 0.0472
# Epoch 24/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0502 - mae: 0.0502 - val_loss: 0.0700 - val_mae: 0.0700
# Epoch 25/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0436 - mae: 0.0436 - val_loss: 0.0229 - val_mae: 0.0229
# Epoch 26/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0419 - mae: 0.0419 - val_loss: 0.0225 - val_mae: 0.0225
# Epoch 27/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0460 - mae: 0.0460 - val_loss: 0.0198 - val_mae: 0.0198
# Epoch 28/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0424 - mae: 0.0424 - val_loss: 0.0144 - val_mae: 0.0144
# Epoch 29/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0397 - mae: 0.0397 - val_loss: 0.0431 - val_mae: 0.0431
# Epoch 30/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0469 - mae: 0.0469 - val_loss: 0.0167 - val_mae: 0.0167
# Epoch 31/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0381 - mae: 0.0381 - val_loss: 0.0346 - val_mae: 0.0346
# Epoch 32/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0434 - mae: 0.0434 - val_loss: 0.0232 - val_mae: 0.0232
# Epoch 33/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0383 - mae: 0.0383 - val_loss: 0.0238 - val_mae: 0.0238
# Epoch 34/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0435 - mae: 0.0435 - val_loss: 0.0329 - val_mae: 0.0329
# Epoch 35/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0426 - mae: 0.0426 - val_loss: 0.0412 - val_mae: 0.0412
# Epoch 36/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0408 - mae: 0.0408 - val_loss: 0.0199 - val_mae: 0.0199
# Epoch 37/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0382 - mae: 0.0382 - val_loss: 0.0376 - val_mae: 0.0376
# Epoch 38/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0398 - mae: 0.0398 - val_loss: 0.0326 - val_mae: 0.0326
# Epoch 39/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0371 - mae: 0.0371 - val_loss: 0.0229 - val_mae: 0.0229
# Epoch 40/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0396 - mae: 0.0396 - val_loss: 0.0196 - val_mae: 0.0196
# Epoch 41/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0396 - mae: 0.0396 - val_loss: 0.0679 - val_mae: 0.0679
# Epoch 42/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0416 - mae: 0.0416 - val_loss: 0.0715 - val_mae: 0.0715
# Epoch 43/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0424 - mae: 0.0424 - val_loss: 0.0328 - val_mae: 0.0328
# Epoch 44/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0379 - mae: 0.0379 - val_loss: 0.0162 - val_mae: 0.0162
# Epoch 45/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0408 - mae: 0.0408 - val_loss: 0.0245 - val_mae: 0.0245
# Epoch 46/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0385 - mae: 0.0385 - val_loss: 0.0405 - val_mae: 0.0405
# Epoch 47/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0388 - mae: 0.0388 - val_loss: 0.0346 - val_mae: 0.0346
# Epoch 48/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0400 - mae: 0.0400 - val_loss: 0.0261 - val_mae: 0.0261
# Epoch 49/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0372 - mae: 0.0372 - val_loss: 0.0185 - val_mae: 0.0185
# Epoch 50/50
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0410 - mae: 0.0410 - val_loss: 0.0123 - val_mae: 0.0123

# %%
# Criando o objeto KerasClassifier
#keras_clf = KerasRegressor(model = get_model, loss="mean_squared_error", optimizer="adam", optimizer__learning_rate= 0.1, hidden_layer_sizes = 100, dropout = 0.0, batch_size=32, verbose=False)
#keras_clf = KerasRegressor(model= get_model(), dropout=0.3,  hidden_layer_sizes= 256, learnRate=1e-2, verbose=False)
keras_clf = KerasRegressor(model=get_model, dropout=0.3, hidden_layer_sizes=256, learning_rate=0.01, loss=mean_absolute_error)

# define a grid of the hyperparameter search space
hidden_layer_sizes = [256, 512]
learnRate = [1e-2, 1e-3]
dropout = [0.3, 0.5]
batchSize = [32]

# create a dictionary from the hyperparameter grid
grid = dict(
	hidden_layer_sizes=hidden_layer_sizes,
	learning_rate=learnRate,
	dropout=dropout,
	batch_size=batchSize
)

## Definindo os valores dos hiperparâmetros
#parameters = {
#    'optimizer': ['sgd', 'adam'],
#    'optimizer__learning_rate': [0.1, 0.001, 0.0001],
#    'model__dropout': [0.3, 0.4, 0.5],
#    'model__hidden_layer_sizes': [100, 300, 600]
#}

# Criando o objeto GridSearchCV
grid_search = GridSearchCV(estimator=keras_clf, param_grid=grid, n_jobs=4, cv=3, error_score='raise')

#tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir="tensorboard", histogram_freq=5000, update_freq='batch', write_grads=True)
#tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir="tensorboard", histogram_freq=5000, update_freq='batch')

# Treinando o grid search
grid_result = grid_search.fit(X_train, y_train, epochs=50, validation_data=(X_val,y_val))




print(grid_result.best_score_, grid_result.best_params_)
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# 2024-05-04 02:50:10.508376: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-04 02:50:10.508785: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-04 02:50:10.510547: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-04 02:50:10.510601: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-04 02:50:10.510913: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-04 02:50:10.512250: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-04 02:50:10.513314: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-04 02:50:10.513391: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-04 02:50:10.515303: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-04 02:50:10.522436: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-04 02:50:10.522591: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-04 02:50:10.526049: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-04 02:50:10.691828: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-04 02:50:10.691879: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-04 02:50:10.694068: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-04 02:50:10.706011: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-04 02:50:14.988980: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13565 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2024-05-04 02:50:14.991946: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13565 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2024-05-04 02:50:14.992118: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13565 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2024-05-04 02:50:15.036634: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 13.25GiB (14224588800 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.037251: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 13.25GiB (14224588800 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.038209: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 11.92GiB (12802129920 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.040231: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 10.73GiB (11521916928 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.041659: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 9.66GiB (10369725440 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.042115: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 11.92GiB (12802129920 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.043643: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 8.69GiB (9332752384 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.044243: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 10.73GiB (11521916928 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.046095: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 7.82GiB (8399476736 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.046616: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 9.66GiB (10369725440 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.048221: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 7.04GiB (7559528960 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.048842: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 8.69GiB (9332752384 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.050379: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 6.34GiB (6803575808 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.050993: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 7.82GiB (8399476736 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.052531: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 5.70GiB (6123217920 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.053134: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 7.04GiB (7559528960 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.054963: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 5.13GiB (5510896128 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.055681: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 6.34GiB (6803575808 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.057233: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 4.62GiB (4959806464 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.057966: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 5.70GiB (6123217920 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.060168: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 4.16GiB (4463825920 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.060949: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 5.13GiB (5510896128 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.061765: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 3.74GiB (4017443328 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.063425: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 4.62GiB (4959806464 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.063984: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 3.37GiB (3615698944 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.072555: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 4.16GiB (4463825920 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.073088: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 3.03GiB (3254128896 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.074732: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 3.74GiB (4017443328 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.075282: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 2.73GiB (2928716032 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.076812: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 3.37GiB (3615698944 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.077448: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 2.45GiB (2635844352 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.078907: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 3.03GiB (3254128896 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.079975: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 2.73GiB (2928716032 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.081115: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 2.45GiB (2635844352 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.081656: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 2.21GiB (2372259840 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.083322: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 2.21GiB (2372259840 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.083819: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 1.99GiB (2135033856 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.085492: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 1.99GiB (2135033856 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.085949: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 1.79GiB (1921530368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.087610: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 1.79GiB (1921530368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.088073: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 1.61GiB (1729377280 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.090314: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 1.61GiB (1729377280 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.090886: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 1.45GiB (1556439552 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.092366: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 1.45GiB (1556439552 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.092867: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 1.30GiB (1400795648 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.094555: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 1.30GiB (1400795648 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.095034: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 1.17GiB (1260716032 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.096546: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 1.17GiB (1260716032 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.097035: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 1.06GiB (1134644480 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.099281: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 1.06GiB (1134644480 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.100585: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 973.87MiB (1021180160 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.101896: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 876.49MiB (919062272 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.103102: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 788.84MiB (827156224 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.104405: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 709.95MiB (744440576 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.105576: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 638.96MiB (669996544 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.106711: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 575.06MiB (602996992 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.108248: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 517.56MiB (542697472 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.110015: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 465.80MiB (488427776 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.111444: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 419.22MiB (439585024 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.112858: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 377.30MiB (395626496 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.114261: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 339.57MiB (356064000 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.115589: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 305.61MiB (320457728 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.119332: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 275.05MiB (288412160 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.121076: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 247.55MiB (259570944 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.122735: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 222.79MiB (233614080 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.124619: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 200.51MiB (210252800 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.126317: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 180.46MiB (189227520 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.127996: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 162.42MiB (170304768 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.129901: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 146.17MiB (153274368 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.131377: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 131.56MiB (137947136 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.132872: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 118.40MiB (124152576 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.134164: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 106.56MiB (111737344 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.136959: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 95.90MiB (100563712 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.138195: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 86.31MiB (90507520 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.139333: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 77.68MiB (81456896 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.140270: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 69.92MiB (73311232 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.141725: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 62.92MiB (65980160 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.143015: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 56.63MiB (59382272 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-05-04 02:50:15.144868: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1101] failed to allocate 50.97MiB (53444096 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 463, in _process_worker
#     r = call_item()
#   File "/opt/conda/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/joblib/parallel.py", line 598, in __call__
#     return [func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/joblib/parallel.py", line 598, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/parallel.py", line 129, in __call__
#     return self.function(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/conda/lib/python3.10/site-packages/scikeras/wrappers.py", line 770, in fit
#     self._fit(
#   File "/opt/conda/lib/python3.10/site-packages/scikeras/wrappers.py", line 925, in _fit
#     X, y = self._initialize(X, y)
#   File "/opt/conda/lib/python3.10/site-packages/scikeras/wrappers.py", line 862, in _initialize
#     self.model_ = self._build_keras_model()
#   File "/opt/conda/lib/python3.10/site-packages/scikeras/wrappers.py", line 433, in _build_keras_model
#     model = final_build_fn(**build_params)
#   File "/var/tmp/ipykernel_18622/3585526308.py", line 5, in get_model
#   File "/opt/conda/lib/python3.10/site-packages/keras/src/models/sequential.py", line 120, in add
#     self._maybe_rebuild()
#   File "/opt/conda/lib/python3.10/site-packages/keras/src/models/sequential.py", line 139, in _maybe_rebuild
#     self.build(input_shape)
#   File "/opt/conda/lib/python3.10/site-packages/keras/src/layers/layer.py", line 223, in build_wrapper
#     original_build_method(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/keras/src/models/sequential.py", line 183, in build
#     x = layer(x)
#   File "/opt/conda/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/context.py", line 603, in ensure_initialized
#     context_handle = pywrap_tfe.TFE_NewContext(opts)
# tensorflow.python.framework.errors_impl.InternalError: cudaSetDevice() on GPU:0 failed. Status: out of memory
# """
#
# The above exception was the direct cause of the following exception:
#
# InternalError                             Traceback (most recent call last)
# Cell In[25], line 35
#      29 grid_search = GridSearchCV(estimator=keras_clf, param_grid=grid, n_jobs=4, cv=3, error_score='raise')
#      31 #tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir="tensorboard", histogram_freq=5000, update_freq='batch', write_grads=True)
#      32 #tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir="tensorboard", histogram_freq=5000, update_freq='batch')
#      33
#      34 # Treinando o grid search
# ---> 35 grid_result = grid_search.fit(X_train, y_train, epochs=50, validation_data=(X_val,y_val))
#      40 print(grid_result.best_score_, grid_result.best_params_)
#      41 means = grid_result.cv_results_['mean_test_score']
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_search.py:970, in BaseSearchCV.fit(self, X, y, **params)
#     964     results = self._format_results(
#     965         all_candidate_params, n_splits, all_out, all_more_results
#     966     )
#     968     return results
# --> 970 self._run_search(evaluate_candidates)
#     972 # multimetric is determined here because in the case of a callable
#     973 # self.scoring the return type is only known after calling
#     974 first_test_score = all_out[0]["test_scores"]
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1527, in GridSearchCV._run_search(self, evaluate_candidates)
#    1525 def _run_search(self, evaluate_candidates):
#    1526     """Search all candidates in param_grid"""
# -> 1527     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_search.py:916, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     908 if self.verbose > 0:
#     909     print(
#     910         "Fitting {0} folds for each of {1} candidates,"
#     911         " totalling {2} fits".format(
#     912             n_splits, n_candidates, n_candidates * n_splits
#     913         )
#     914     )
# --> 916 out = parallel(
#     917     delayed(_fit_and_score)(
#     918         clone(base_estimator),
#     919         X,
#     920         y,
#     921         train=train,
#     922         test=test,
#     923         parameters=parameters,
#     924         split_progress=(split_idx, n_splits),
#     925         candidate_progress=(cand_idx, n_candidates),
#     926         **fit_and_score_kwargs,
#     927     )
#     928     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     929         enumerate(candidate_params),
#     930         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     931     )
#     932 )
#     934 if len(out) < 1:
#     935     raise ValueError(
#     936         "No fits were performed. "
#     937         "Was the CV iterator empty? "
#     938         "Were there no candidates?"
#     939     )
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/utils/parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File /opt/conda/lib/python3.10/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reach the first `yield` statement. This starts the aynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File /opt/conda/lib/python3.10/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File /opt/conda/lib/python3.10/site-packages/joblib/parallel.py:1754, in Parallel._retrieve(self)
#    1747 while self._wait_retrieval():
#    1748
#    1749     # If the callback thread of a worker has signaled that its task
#    1750     # triggered an exception, or if the retrieval loop has raised an
#    1751     # exception (e.g. `GeneratorExit`), exit the loop and surface the
#    1752     # worker traceback.
#    1753     if self._aborting:
# -> 1754         self._raise_error_fast()
#    1755         break
#    1757     # If the next job is not ready for retrieval yet, we just wait for
#    1758     # async callbacks to progress.
#
# File /opt/conda/lib/python3.10/site-packages/joblib/parallel.py:1789, in Parallel._raise_error_fast(self)
#    1785 # If this error job exists, immediatly raise the error by
#    1786 # calling get_result. This job might not exists if abort has been
#    1787 # called directly or if the generator is gc'ed.
#    1788 if error_job is not None:
# -> 1789     error_job.get_result(self.timeout)
#
# File /opt/conda/lib/python3.10/site-packages/joblib/parallel.py:745, in BatchCompletionCallBack.get_result(self, timeout)
#     739 backend = self.parallel._backend
#     741 if backend.supports_retrieve_callback:
#     742     # We assume that the result has already been retrieved by the
#     743     # callback thread, and is stored internally. It's just waiting to
#     744     # be returned.
# --> 745     return self._return_or_raise()
#     747 # For other backends, the main thread needs to run the retrieval step.
#     748 try:
#
# File /opt/conda/lib/python3.10/site-packages/joblib/parallel.py:763, in BatchCompletionCallBack._return_or_raise(self)
#     761 try:
#     762     if self.status == TASK_ERROR:
# --> 763         raise self._result
#     764     return self._result
#     765 finally:
#
# InternalError: cudaSetDevice() on GPU:0 failed. Status: out of memory

# %%
testt = keras_clf.get_params().keys()
testt
